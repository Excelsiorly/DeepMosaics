# %% [markdown]
# <a href="https://colab.research.google.com/github/Excelsiorly/DeepMosaics/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# !/opt/bin/nvidia-smi
# Out:
# Tue Jun 13 04:17:20 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !conda --version
# Out:
# /bin/bash: conda: command not found

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------------
# absl-py                       1.4.0
# alabaster                     0.7.13
# albumentations                1.2.1
# altair                        4.2.2
# anyio                         3.6.2
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# array-record                  0.2.0
# arviz                         0.15.1
# astropy                       5.2.2
# astunparse                    1.6.3
# attrs                         23.1.0
# audioread                     3.0.0
# autograd                      1.5
# Babel                         2.12.1
# backcall                      0.2.0
# beautifulsoup4                4.11.2
# bleach                        6.0.0
# blis                          0.7.9
# blosc2                        2.0.0
# bokeh                         2.4.3
# branca                        0.6.0
# ...

# %%
# !screen
# Out:
# /bin/bash: screen: command not found

# %%
# !apt-get install screen
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Suggested packages:
#   byobu | screenie | iselect ncurses-term
# The following NEW packages will be installed:
#   screen
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 577 kB of archives.
# After this operation, 1,022 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 screen amd64 4.8.0-1ubuntu0.1 [577 kB]
# Fetched 577 kB in 1s (407 kB/s)
# Selecting previously unselected package screen.
# (Reading database ... 122541 files and directories currently installed.)
# Preparing to unpack .../screen_4.8.0-1ubuntu0.1_amd64.deb ...
# Unpacking screen (4.8.0-1ubuntu0.1) ...
# Setting up screen (4.8.0-1ubuntu0.1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for systemd (245.4-4ubuntu3.21) ...

# %%
# 检查anaconda是否安装成功
# !conda --version   #在ipynb中执行终端命令时需要加上感叹号
# Out:
# conda 4.5.11

# %%
# !wget https://repo.anaconda.com/archive/Anaconda3-5.3.0-Linux-x86_64.sh
# !bash Anaconda3-5.3.0-Linux-x86_64.sh -bfp /usr/local
# Out:
# --2023-06-13 04:21:58--  https://repo.anaconda.com/archive/Anaconda3-5.3.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 667822837 (637M) [application/x-sh]
# Saving to: ‘Anaconda3-5.3.0-Linux-x86_64.sh’
#
# Anaconda3-5.3.0-Lin 100%[===================>] 636.88M   213MB/s    in 3.0s
#
# 2023-06-13 04:22:01 (213 MB/s) - ‘Anaconda3-5.3.0-Linux-x86_64.sh’ saved [667822837/667822837]
#
# PREFIX=/usr/local
# reinstalling: python-3.7.0-hc3d631a_0 ...
# Python 3.7.0
# reinstalling: blas-1.0-mkl ...
# reinstalling: ca-certificates-2018.03.07-0 ...
# reinstalling: conda-env-2.6.0-1 ...
# reinstalling: intel-openmp-2019.0-118 ...
# reinstalling: libgcc-ng-8.2.0-hdf63c60_1 ...
# reinstalling: libgfortran-ng-7.3.0-hdf63c60_0 ...
# ...
